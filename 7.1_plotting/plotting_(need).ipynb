# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %% [markdown]
# ### Things to note

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75   # this will give the error bars which are seen as 'plus signs'

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,   # abbreviating the error names
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=0.25)  # the alpha value regulates the transparency of a graph plot
plt.legend(loc='upper left')   # shows us the labels
plt.savefig('plot.png', dpi=150)     # this will save in the notebook under plotting files
plt.show()

# %% [markdown]
# here is how we can write abbreviations (both will give the same result):
#
# plt.plot(x, y, color='red', linestyle='dashed', linewidth=2)
#
# plt.plot(x, y, c='red', ls='dashed', lw=2)

# %% [markdown]
# here is how we can use the for loop in plots and its outputs:

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
for alpha in [.25, .75, 1]:
    plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
    plt.plot(x, y_2, label='Y2 values', color='blue', )
    plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
    plt.xlabel('x-values')
    plt.ylabel('y-values')
    plt.title('X vs Y')
    plt.grid(alpha=.25)
    plt.legend(loc='upper left')
    plt.savefig('plot pdf', dpi =300)

# %% [markdown]
# can use plt.clf() to clear the figure

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %% [markdown]
# ### Things to note:

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x = np.linspace(0, 6, 100)     #The improvement is seen in the plot on the right.
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %% [markdown]
# # 3 Saving to disc

# %% [markdown]
# basically just saving the files in different types etc, the resolution using the dpi thing.

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
np.loadtxt('https://berkeley-earth-temperature.s3.us-west-1.amazonaws.com/Global/Complete_TAVG_daily.txt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: '%'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 np.loadtxt('https://berkeley-earth-temperature.s3.us-west-1.amazonaws.com/Global/Complete_TAVG_daily.txt')
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:1381, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1378 if isinstance(delimiter, bytes):
#    1379     delimiter = delimiter.decode('latin1')
# -> 1381 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382             converters=converters, skiplines=skiprows, usecols=usecols,
#    1383             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1384             max_rows=max_rows, quote=quotechar)
#    1386 return arr
#
# File ~\miniconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:1021, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1018     data = _preprocess_comments(data, comments, encoding)
#    1020 if read_dtype_via_object_chunks is None:
# -> 1021     arr = _load_from_filelike(
#    1022         data, delimiter=delimiter, comment=comment, quote=quote,
#    1023         imaginary_unit=imaginary_unit,
#    1024         usecols=usecols, skiplines=skiplines, max_rows=max_rows,
#    1025         converters=converters, dtype=dtype,
#    1026         encoding=encoding, filelike=filelike,
#    1027         byte_converters=byte_converters)
#    1029 else:
#    1030     # This branch reads the file into chunks of object arrays and then
#    1031     # casts them to the desired actual dtype.  This ensures correct
#    1032     # string-length and datetime-unit discovery (like `arr.astype()`).
#    1033     # Due to chunking, certain error reports are less clear, currently.
#    1034     if filelike:
#
# ValueError: could not convert string '%' to float64 at row 0, column 1.

# %%
file_url = 'https://berkeley-earth-temperature.s3.us-west-1.amazonaws.com/Global/Complete_TAVG_daily.txt'

data = np.loadtxt(file_url, skiprows = 23) # skips the 23 rows with the % which numpy knows is not numbers 
                                    # but np not smart enough to exclude it

plt.plot(data[:,1],data[:,-1], alpha =.5)

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
# Your code here

# %% [markdown]
# ### Resetting styles

# %%
# Your code here
